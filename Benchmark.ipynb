# %%
import pandas as pd
import numpy as np
import os, json
import nltk

# %%
DATAPATH = 'data'
CSV_FILEPATH ="/".join([DATAPATH, 'metadata_ft_subset.csv'])

# %%
df = pd.read_csv(CSV_FILEPATH)
print(df.shape)
df.head()
# Out:
# (33499, 19)
#    cord_uid                                       sha source_x  \
# 0  xqhn0vbp  1e1286db212100993d03cc22374b624f7caee956      PMC
# 1  gi6uaa83  8ae137c8da1607b3a8e4c946c07ca8bda67f88ac      PMC
# 3  fy4w7xz8  0104f6ceccf92ae8567a0102f89cbb976969a774      PMC
# 4  0qaoam29  5b68a553a7cbbea13472721cd1ad617d42b40c26      PMC
# 5  qj4dh6rg  3ed670f60a7be2e3e2a991ea8af1fdd5fa5e2b2c      PMC
#
#                                                title                      doi  \
# 0  Airborne rhinovirus detection and effect of ul...    10.1186/1471-2458-3-5
# 1    Discovering human history from stomach bacteria  10.1186/gb-2003-4-5-213
# 3  Association of HLA class I with severe acute r...    10.1186/1471-2350-4-9
# 4   A double epidemic model for the SARS propagation   10.1186/1471-2334-3-19
# 5  Cloaked similarity between HIV-1 and SARS-CoV ...   10.1186/1471-2180-3-20
#
#        pmcid   pubmed_id license  \
# 0  PMC140314  12525263.0   no-cc
# 1  PMC156578  12734001.0   no-cc
# 3  PMC212558  12969506.0   no-cc
# 4  PMC222908  12964944.0   no-cc
# 5  PMC222911  14499001.0   no-cc
#
#                                             abstract publish_time  \
# 0  BACKGROUND: Rhinovirus, the most common cause ...   2003-01-13
# 1  Recent analyses of human pathogens have reveal...   2003-04-28
# 3  BACKGROUND: The human leukocyte antigen (HLA) ...   2003-09-12
# 4  BACKGROUND: An epidemic of a Severe Acute Resp...   2003-09-10
# 5  BACKGROUND: Severe acute respiratory syndrome ...   2003-09-21
#
#                                              authors            journal  \
# 0  Myatt, Theodore A; Johnston, Sebastian L; Rudn...  BMC Public Health
# 1                                   Disotell, Todd R        Genome Biol
# 3  Lin, Marie; Tseng, Hsiang-Kuang; Trejaut, Jean...      BMC Med Genet
# 4  Ng, Tuen Wai; Turinici, Gabriel; Danchin, Antoine     BMC Infect Dis
# 5                    Kliger, Yossef; Levanon, Erez Y      BMC Microbiol
#
#    Microsoft Academic Paper ID WHO #Covidence  has_pdf_parse  \
# 0                          NaN            NaN           True
# 1                          NaN            NaN           True
# 3                          NaN            NaN           True
# 4                          NaN            NaN           True
# 5                          NaN            NaN           True
#
#    has_pmc_xml_parse  full_text_file  \
# 0               True  custom_license
# 1               True  custom_license
# 3               True  custom_license
# 4               True  custom_license
# 5               True  custom_license
#
#                                                  url  \
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1...
# 3  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
# 5  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
#
#                                       full_body_text
# 0  Rhinoviruses have been associated with 40% to ...
# 1  Charles Darwin recognized that the distributio...
# 3  patient group  a further significant increase ...
# 4  Since November 2002 (and perhaps earlier) an o...
# 5  Infection by many enveloped viruses requires f...

# %%
def extract_simple_docs(df):
    docs = []
    for row in df.iterrows():
        abstract = row[1]['abstract']
        title = row[1]['title']
        if len(title) < 20:
            title = ''
        doc = title + ' ' + abstract
        docs.append(doc)
    
    return docs

# %%
docs = extract_simple_docs(df)
len(docs)
# Out:
# 33499

# %%
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords 
# Split the documents into tokens.
def simple_preprocess(docs):
    new_docs = []
    stop_words = set(stopwords.words('english'))
    tokenizer = RegexpTokenizer(r'\w+')
    for idx in range(len(docs)):
        new_doc = docs[idx].lower()  # Convert to lowercase.
        new_doc = tokenizer.tokenize(new_doc)  # Split into words.
        new_doc = [token for token in new_doc if not token.isnumeric()]
        new_doc = [token for token in new_doc if len(token) > 1]
        new_doc = [token for token in new_doc if token not in stop_words]
        new_docs.append(new_doc)
    
    return new_docs

# %%
docs = simple_preprocess(docs)
print(len(docs))
# Out:
# 33499

# %%
from gensim.corpora import Dictionary

# Create a dictionary representation of the documents.
dictionary = Dictionary(docs)

# Filter out words that occur less than 20 documents, or more than 50% of the documents.
dictionary.filter_extremes(no_below=20, no_above=0.5)

# %%
corpus = [dictionary.doc2bow(doc) for doc in docs]

# %%
print('Number of unique tokens: %d' % len(dictionary))
print('Number of documents: %d' % len(corpus))
# Out:
# Number of unique tokens: 10987
# Number of documents: 33499

# %% [markdown]
# <h3> The benchmark model uses all gensim defaults, including num_topics which I set for later use

# %%
from gensim.models import LdaMulticore

# Set training parameters.
passes = 10
num_topics = 100

# Make a index to word dictionary.
temp = dictionary[0]  # This is only to "load" the dictionary.
id2word = dictionary.id2token

model = LdaMulticore(
    corpus=corpus,
    id2word=id2word,
    passes=passes,
    num_topics=num_topics
)

# %%
model.save('models/lda_abs_bench/model_v7')

# %%
top_topics = model.top_topics(texts=docs, dictionary=dictionary, coherence='c_v') #, num_words=20)

# Average topic coherence is the sum of topic coherences of all topics, divided by the number of topics.
avg_topic_coherence = sum([t[1] for t in top_topics]) / num_topics
print('Average topic coherence: ', avg_topic_coherence)
rstd_atc = np.std([t[1] for t in top_topics]) / avg_topic_coherence
print('Relative Standard Deviation of ATC: ', rstd_atc)
# Out:
# Average topic coherence:  0.5335285079238352
# Relative Standard Deviation of ATC:  0.2662799718130911

# %%
# Check a topic distribution

new_doc = docs[0]
doc_vector = dictionary.doc2bow(new_doc)
model[doc_vector]
# Out:
# [(13, 0.015835749),
#  (30, 0.02814486),
#  (35, 0.12532902),
#  (36, 0.040171918),
#  (47, 0.20075439),
#  (61, 0.28207725),
#  (66, 0.3019729)]

# %%
model.show_topics(num_topics=num_topics, num_words=20, formatted=True)
top_topics
# Out:
# [([(0.1240785, 'de'),
#    (0.060605917, 'la'),
#    (0.05165783, 'en'),
#    (0.034862872, 'el'),
#    (0.02892443, 'los'),
#    (0.023115918, 'las'),
#    (0.022890788, 'se'),
#    (0.016862249, 'con'),
#    (0.013621552, 'que'),
#    (0.012769645, 'del'),
#    (0.011264129, 'por'),
#    (0.011214013, 'un'),
#    (0.010939007, 'virus'),
#    (0.010915431, 'una'),
#    (0.010268765, 'para'),
#    (0.0093788495, 'es'),
#    (0.007584954, 'infecciones'),
#    (0.006470929, 'pacientes'),
#    (0.0063841096, 'más'),
#    (0.005906935, 'son')],
#   0.9388854688476913),
#  ([(0.054600023, 'de'),
#    (0.04136689, 'et'),
#    (0.034454606, 'des'),
#    (0.03361163, 'les'),
#    (0.02903918, 'la'),
#    (0.021339275, 'le'),
#    (0.020213023, 'une'),
#    (0.017838268, 'en'),
#    (0.016642507, 'virus'),
#    (0.013871503, 'infections'),
#    (0.01385818, 'un'),
#    (0.012235059, 'dans'),
#    (0.010907034, 'est'),
#    (0.0108766155, 'par'),
#    (0.0100451205, 'du'),
#    (0.009100237, 'sont'),
#    (0.008126675, 'hmpv'),
#    (0.00809403, 'infection'),
#    (0.00803842, 'ou'),
#    (0.008011857, 'respiratory')],
#   0.7694775491019036),
#  ([(0.03959777, 'cells'),
#    (0.01887523, 'ifn'),
#    (0.01809395, 'induced'),
#    (0.017823776, 'expression'),
#    (0.015450524, 'cell'),
#    (0.013763058, 'infection'),
#    (0.013159295, 'activation'),
#    (0.010440612, 'apoptosis'),
#    (0.009776527, 'signaling'),
#    (0.0088700745, 'response'),
#    (0.008494726, 'production'),
#    (0.008086774, 'interferon'),
#    (0.0074885725, 'macrophages'),
#    (0.007382368, 'immune'),
#    (0.0062988712, 'mediated'),
#    (0.0060724155, 'pathway'),
#    (0.0057712984, 'induction'),
#    (0.0056639765, 'infected'),
#    (0.0052852035, 'factor'),
#    (0.0052505997, 'type')],
#   0.7643372675810398),
#  ([(0.052945588, 'mers'),
#    (0.03700285, 'cov'),
#    (0.032955833, 'bats'),
#    (0.03003765, 'bat'),
#    (0.023922984, 'east'),
#    (0.022306988, 'middle'),
#    (0.0148197515, 'respiratory'),
#    (0.0145534, 'coronavirus'),
#    (0.01441416, 'camels'),
#    (0.012827606, 'human'),
#    (0.0125516625, 'syndrome'),
#    (0.0109544145, 'species'),
#    (0.010568907, 'virus'),
#    (0.009035576, 'transmission'),
#    (0.008852431, 'infection'),
#    (0.008531844, 'coronaviruses'),
#    (0.007932653, 'humans'),
#    (0.007783664, 'dromedary'),
#    (0.007748522, 'camel'),
#    (0.0075207124, 'covs')],
#   0.761842684313103),
#  ([(0.023503274, 'structure'),
#    (0.022393016, 'protein'),
#    (0.016310927, 'domain'),
#    (0.013763819, 'structural'),
#    (0.013071044, 'binding'),
#    (0.012256572, 'proteins'),
#    (0.010709874, 'structures'),
#    (0.008999754, 'domains'),
#    (0.007341551, 'interactions'),
#    (0.0071492773, 'fusion'),
#    (0.0070187286, 'membrane'),
#    (0.00629194, 'crystal'),
#    (0.0062599354, 'residues'),
#    (0.0061883633, 'two'),
#    (0.00568285, 'form'),
#    (0.005551897, 'helix'),
#    (0.0054783276, 'adp'),
#    (0.005348385, 'molecular'),
#    (0.0050031897, 'complex'),
#    (0.00479226, 'conformation')],
#   0.75233768152829),
#  ([(0.041480716, 'ace2'),
#    (0.029901525, 'angiotensin'),
#    (0.015128842, 'enzyme'),
#    (0.014142801, 'converting'),
#    (0.013567694, 'lung'),
#    (0.01344796, 'ii'),
#    (0.013180748, 'injury'),
#    (0.0125464285, 'ace'),
#    (0.012084087, 'heart'),
#    (0.009888901, 'ang'),
#    (0.009253036, 'diabetes'),
#    (0.008697626, 'receptor'),
#    (0.008186462, 'kidney'),
#    (0.008146707, 'cardiovascular'),
#    (0.007968467, 'renal'),
#    (0.007601771, 'expression'),
#    (0.0074922517, 'ras'),
#    (0.007124583, 'acute'),
#    (0.007092837, 'disease'),
#    (0.0070597855, 'cardiac')],
#   0.7472481363611345),
#  ([(0.026215043, 'virus'),
#    (0.024525613, 'cns'),
#    (0.023662964, 'mice'),
#    (0.020235753, 'infection'),
#    (0.018204216, 'brain'),
#    (0.017506137, 'nervous'),
#    (0.017311674, 'disease'),
#    (0.016681887, 'viral'),
#    (0.01550317, 'central'),
#    (0.0145560615, 'system'),
#    (0.013177514, 'hepatitis'),
#    (0.0123259, 'encephalitis'),
#    (0.010812183, 'demyelination'),
#    (0.009512315, 'encephalomyelitis'),
#    (0.009306448, 'ms'),
#    (0.008645113, 'acute'),
#    (0.0084342845, 'multiple'),
#    (0.007851396, 'sclerosis'),
#    (0.007159908, 'demyelinating'),
#    (0.006873133, 'neurological')],
#   0.738657366683592),
#  ([(0.028447026, 'membrane'),
#    (0.02551246, 'virus'),
#    (0.0194534, 'fusion'),
#    (0.018467134, 'viral'),
#    (0.016309042, 'cell'),
#    (0.014214872, 'proteins'),
#    (0.010916304, 'protein'),
#    (0.010212542, 'entry'),
#    (0.008865645, 'viruses'),
#    (0.008504756, 'membranes'),
#    (0.008456713, 'cells'),
#    (0.006908652, 'replication'),
#    (0.0065857405, 'glycoprotein'),
#    (0.006442106, 'particles'),
#    (0.0063681128, 'surface'),
#    (0.0061171865, 'binding'),
#    (0.005890298, 'host'),
#    (0.005873887, 'golgi'),
#    (0.0054706787, 'envelope'),
#    (0.0053513, 'cellular')],
#   0.7333045846238806),
#  ([(0.029850641, 'antibody'),
#    (0.029620925, 'antibodies'),
#    (0.01667825, 'specific'),
#    (0.014850896, 'responses'),
#    (0.014224097, 'neutralizing'),
#    (0.01307182, 'virus'),
#    (0.0129024945, 'immune'),
#    (0.011815965, 'vaccine'),
#    (0.010849073, 'mice'),
#    (0.010574852, 'antigen'),
#    (0.010343705, 'protein'),
#    (0.009769797, 'monoclonal'),
#    (0.009015988, 'cell'),
#    (0.00861111, 'anti'),
#    (0.008459421, 'epitopes'),
#    (0.0073823663, 'response'),
#    (0.0070551224, 'epitope'),
#    (0.0069650626, 'human'),
#    (0.0068362555, 'igg'),
#    (0.006806022, 'cells')],
#   0.7174982169656356),
#  ([(0.052963704, 'pedv'),
#    (0.045414295, 'porcine'),
#    (0.028500434, 'diarrhea'),
#    (0.02782462, 'virus'),
#    (0.02667048, 'pigs'),
#    (0.023857651, 'tgev'),
#    (0.020749614, 'piglets'),
#    (0.018245028, 'epidemic'),
#    (0.016278896, 'swine'),
#    (0.015032136, 'infection'),
#    (0.010907081, 'pdcov'),
#    (0.010896917, 'gastroenteritis'),
#    (0.010246288, 'strain'),
#    (0.009973966, 'transmissible'),
#    (0.009648584, 'infected'),
#    (0.007992113, 'pig'),
#    (0.0068821814, 'strains'),
#    (0.006387062, 'study'),
#    (0.0063102106, 'intestinal'),
#    (0.0058389134, 'mir')],
#   0.7139743552721989),
#  ([(0.09028399, 'rna'),
#    (0.017281909, 'viral'),
#    (0.015937159, 'virus'),
#    (0.014228493, 'genome'),
#    (0.010946012, 'sequence'),
#    (0.0109143555, 'rnas'),
#    (0.009366218, 'viruses'),
#    (0.008065986, 'sequences'),
#    (0.007962541, 'polymerase'),
#    (0.0078698015, 'synthesis'),
#    (0.0077613094, 'strand'),
#    (0.007460392, 'genomic'),
#    (0.006878845, 'recombination'),
#    (0.0066457535, 'mrna'),
#    (0.006337781, 'replication'),
#    (0.0057018404, 'dna'),
#    (0.00551144, 'stranded'),
#    (0.0053231195, 'transcription'),
#    (0.0050668763, 'mrnas'),
#    (0.0049988716, 'length')],
#   0.7032975592139693),
#  ([(0.035043895, 'china'),
#    (0.028683465, 'cases'),
#    (0.01622208, 'covid'),
#    (0.0147036975, 'outbreak'),
#    (0.014593899, 'transmission'),
#    (0.011445778, 'wuhan'),
#    (0.010734559, 'ncov'),
#    (0.0098508345, 'coronavirus'),
#    (0.008609613, 'data'),
#    (0.008561747, 'case'),
#    (0.008242198, 'epidemic'),
#    (0.007796158, 'confirmed'),
#    (0.007014722, 'reported'),
#    (0.007012008, 'novel'),
#    (0.006713187, 'province'),
#    (0.006697309, 'countries'),
#    (0.006646468, 'spread'),
#    (0.0060766195, 'number'),
#    (0.006053153, 'infection'),
#    (0.005792825, 'january')],
#   0.6972451299986497),
#  ([(0.038688395, 'bovine'),
#    (0.033318006, 'rotavirus'),
#    (0.020014795, 'cattle'),
#    (0.013908457, 'coli'),
#    (0.01345886, 'diarrhea'),
#    (0.011837774, 'spp'),
#    (0.011456188, 'pathogens'),
#    (0.011117794, 'samples'),
#    (0.009157324, 'enteric'),
#    (0.008934912, 'diarrhoea'),
#    (0.0077447062, 'bacteria'),
#    (0.007354169, 'brsv'),
#    (0.007109574, 'salmonella'),
#    (0.0064839097, 'calves'),
#    (0.006333477, 'animals'),
#    (0.0062888456, 'abstract'),
#    (0.006263004, 'detected'),
#    (0.005960506, 'escherichia'),
#    (0.0056289877, 'infections'),
#    (0.0055527263, 'bvdv')],
#   0.6941689895936525),
#  ([(0.043429323, 'calves'),
#    (0.012866945, 'days'),
#    (0.009995722, 'calf'),
#    (0.008796976, 'study'),
#    (0.008614302, 'group'),
#    (0.008153044, 'dairy'),
#    (0.008151854, 'milk'),
#    (0.007929383, 'colostrum'),
#    (0.0073223165, 'day'),
#    (0.0069352817, 'age'),
#    (0.0068578585, 'diarrhea'),
#    (0.006507956, 'groups'),
#    (0.006293452, 'fed'),
#    (0.006100395, 'control'),
#    (0.005774257, 'cryptosporidium'),
#    (0.005721807, 'treatment'),
#    (0.005431011, 'abstract'),
#    (0.0052521946, 'herds'),
#    (0.005154137, 'weight'),
#    (0.005101207, 'kg')],
#   0.6912218394491075),
#  ([(0.0590272, 'respiratory'),
#    (0.02892693, 'viral'),
#    (0.028317377, 'children'),
#    (0.027015073, 'infections'),
#    (0.023811365, 'rsv'),
#    (0.01885207, 'infection'),
#    (0.01849998, 'virus'),
#    (0.016345466, 'tract'),
#    (0.013446445, 'viruses'),
#    (0.011318028, 'syncytial'),
#    (0.009396185, 'human'),
#    (0.0093758255, 'acute'),
#    (0.008540818, 'clinical'),
#    (0.007776102, 'infants'),
#    (0.0077737705, 'rhinovirus'),
#    (0.007753061, 'associated'),
#    (0.0076656137, 'patients'),
#    (0.007510366, 'bacterial'),
#    (0.007505299, 'lower'),
#    (0.007212851, 'hmpv')],
#   0.6866303207539447),
#  ([(0.040452976, 'pcr'),
#    (0.036570124, 'detection'),
#    (0.025450954, 'assay'),
#    (0.022976737, 'rt'),
#    (0.018427001, 'samples'),
#    (0.016141426, 'time'),
#    (0.013962969, 'real'),
#    (0.013666249, 'virus'),
#    (0.01262299, 'assays'),
#    (0.011466074, 'using'),
#    (0.011166194, 'rapid'),
#    (0.010870592, 'sensitivity'),
#    (0.009483897, 'reaction'),
#    (0.009207194, 'clinical'),
#    (0.009174191, 'diagnostic'),
#    (0.009135435, 'method'),
#    (0.008661231, 'positive'),
#    (0.007826277, 'amplification'),
#    (0.0076856827, 'viruses'),
#    (0.007667426, 'results')],
#   0.6859891543534804),
#  ([(0.036352288, 'patients'),
#    (0.017796401, 'respiratory'),
#    (0.01772742, 'covid'),
#    (0.016985428, 'mers'),
#    (0.015391498, 'cases'),
#    (0.014442921, 'syndrome'),
#    (0.014128572, 'cov'),
#    (0.013689728, 'severe'),
#    (0.013539651, 'clinical'),
#    (0.012725702, 'infection'),
#    (0.012256417, 'coronavirus'),
#    (0.011959459, 'disease'),
#    (0.008070466, 'case'),
#    (0.007874344, 'acute'),
#    (0.006828987, 'middle'),
#    (0.0066450504, 'symptoms'),
#    (0.0065756813, 'patient'),
#    (0.0065422435, 'pneumonia'),
#    (0.006418684, 'east'),
#    (0.0060784244, 'confirmed')],
#   0.6691847390893553),
#  ([(0.024663571, 'sars'),
#    (0.022098321, 'coronavirus'),
#    (0.020826241, 'protein'),
#    (0.016428242, 'cov'),
#    (0.01567376, 'proteins'),
#    (0.012490618, 'protease'),
#    (0.011191626, 'like'),
#    (0.009620129, 'amino'),
#    (0.009243878, 'structural'),
#    (0.008188861, 'cleavage'),
#    (0.0075163986, 'coronaviruses'),
#    (0.007246091, 'structure'),
#    (0.0071700006, 'two'),
#    (0.006885724, 'domain'),
#    (0.006647971, 'residues'),
#    (0.006457545, '3c'),
#    (0.0063308976, 'site'),
#    (0.0062787607, 'respiratory'),
#    (0.0062738545, 'conserved'),
#    (0.006187155, 'terminal')],
#   0.6646537567415877),
#  ([(0.08723677, 'vaccine'),
#    (0.044059288, 'vaccines'),
#    (0.019837908, 'virus'),
#    (0.018779503, 'vaccination'),
#    (0.012839408, 'live'),
#    (0.012385492, 'vectors'),
#    (0.012382518, 'vector'),
#    (0.012231736, 'recombinant'),
#    (0.011458286, 'vaccinated'),
#    (0.010717878, 'protection'),
#    (0.0104284, 'attenuated'),
#    (0.009279051, 'challenge'),
#    (0.0092422115, 'dna'),
#    (0.008987913, 'efficacy'),
#    (0.008972605, 'adenovirus'),
#    (0.00806267, 'based'),
#    (0.0057088877, 'development'),
#    (0.0053523756, 'immunogenicity'),
#    (0.005230226, 'dose'),
#    (0.005055777, 'effective')],
#   0.6511061117267126),
#  ([(0.027214589, 'protein'),
#    (0.022999868, 'replication'),
#    (0.020483969, 'viral'),
#    (0.017543359, 'cells'),
#    (0.01612227, 'virus'),
#    (0.015487676, 'rna'),
#    (0.012952403, 'infection'),
#    (0.012001376, 'cell'),
#    (0.010240654, 'host'),
#    (0.010076613, 'cellular'),
#    (0.010051348, 'proteins'),
#    (0.008302503, 'expression'),
#    (0.006946661, 'cycle'),
#    (0.006339448, 'translation'),
#    (0.0057404535, 'role'),
#    (0.005736314, 'infected'),
#    (0.0050099446, 'autophagy'),
#    (0.004885223, 'also'),
#    (0.0047021527, 'binding'),
#    (0.0047018323, 'transcription')],
#   0.6504438435713731),
#  ([(0.045168106, 'elisa'),
#    (0.02703588, 'sera'),
#    (0.020407993, 'antibodies'),
#    (0.018172069, 'serum'),
#    (0.01780781, 'positive'),
#    (0.017205788, 'test'),
#    (0.016463831, 'samples'),
#    (0.012571434, 'linked'),
#    (0.012445337, 'enzyme'),
#    (0.011889527, 'immunosorbent'),
#    (0.011799663, 'serological'),
#    (0.011302598, 'antibody'),
#    (0.010634783, 'assay'),
#    (0.009827727, 'reference'),
#    (0.009551266, 'results'),
#    (0.008780752, 'tests'),
#    (0.008354377, 'using'),
#    (0.008329392, 'western'),
#    (0.007865651, 'igg'),
#    (0.007576372, 'used')],
#   0.6500093280855015),
#  ([(0.06086952, 'asthma'),
#    (0.035083268, 'exacerbations'),
#    (0.031765528, 'copd'),
#    (0.025887048, 'patients'),
#    (0.020955523, 'exacerbation'),
#    (0.020228527, 'airway'),
#    (0.01893059, 'chronic'),
#    (0.01610481, 'pulmonary'),
#    (0.010859886, 'obstructive'),
#    (0.01024228, 'sputum'),
#    (0.010043756, 'acute'),
#    (0.008394724, 'bacterial'),
#    (0.00814559, 'associated'),
#    (0.00716414, 'serum'),
#    (0.007118446, 'subjects'),
#    (0.006826843, 'disease'),
#    (0.0067086536, 'levels'),
#    (0.0066844826, 'infection'),
#    (0.0064614564, 'viral'),
#    (0.006188817, 'lung')],
#   0.6486193259028562),
#  ([(0.02068105, 'care'),
#    (0.012532643, 'hospital'),
#    (0.011799783, 'healthcare'),
#    (0.0108388765, 'hospitals'),
#    (0.010486842, 'health'),
#    (0.010484048, 'infection'),
#    (0.010156263, 'control'),
#    (0.010094788, 'workers'),
#    (0.009876966, 'use'),
#    (0.009735104, 'patient'),
#    (0.008247385, 'study'),
#    (0.007499422, 'patients'),
#    (0.0069873985, 'mask'),
#    (0.0068986146, 'results'),
#    (0.006878497, 'medical'),
#    (0.0067048008, 'masks'),
#    (0.006657083, 'equipment'),
#    (0.0066323527, 'ppe'),
#    (0.006060473, 'protective'),
#    (0.0057837283, 'methods')],
#   0.6408173743956286),
#  ([(0.06196989, 'cells'),
#    (0.023138717, 'cell'),
#    (0.018444816, 'sirna'),
#    (0.015181403, 'virus'),
#    (0.013227148, 'rnai'),
#    (0.012069097, 'expression'),
#    (0.011792105, 'infected'),
#    (0.011533776, 'viral'),
#    (0.010479218, 'cultures'),
#    (0.009702945, 'infection'),
#    (0.008718615, 'gene'),
#    (0.0083760945, 'vivo'),
#    (0.008164008, 'vitro'),
#    (0.007847943, 'lines'),
#    (0.007783566, 'interference'),
#    (0.0076634414, 'culture'),
#    (0.0073712347, 'sirnas'),
#    (0.006897502, 'specific'),
#    (0.006798215, 'replication'),
#    (0.006700325, 'rna')],
#   0.6328156628586294),
#  ([(0.040835667, 'health'),
#    (0.018080272, 'public'),
#    (0.0073114894, 'disease'),
#    (0.007274829, 'global'),
#    (0.0065242685, 'risk'),
#    (0.0062454063, 'infectious'),
#    (0.005985658, 'response'),
#    (0.005277757, 'countries'),
#    (0.0051952465, 'control'),
#    (0.0051140995, 'outbreak'),
#    (0.0048662266, 'pandemic'),
#    (0.004791291, 'international'),
#    (0.0046761674, 'information'),
#    (0.004583439, 'knowledge'),
#    (0.0044928994, 'china'),
#    (0.0044762017, 'diseases'),
#    (0.004382401, 'emergency'),
#    (0.004342855, 'preparedness'),
#    (0.004107273, 'study'),
#    (0.0038312967, 'national')],
#   0.6324983918375918),
#  ([(0.15588188, 'sars'),
#    (0.1085173, 'cov'),
#    (0.0344727, 'coronavirus'),
#    (0.027543643, 'syndrome'),
#    (0.024694318, 'respiratory'),
#    (0.023014951, 'severe'),
#    (0.021995984, 'mers'),
#    (0.021467727, 'acute'),
#    (0.014881021, 'protein'),
#    (0.0093693575, 'spike'),
#    (0.0066985013, 'rbd'),
#    (0.006112882, 'patients'),
#    (0.0058842637, 'infection'),
#    (0.005460908, 'human'),
#    (0.0047609755, 'binding'),
#    (0.004533703, 'receptor'),
#    (0.004276453, 'study'),
#    (0.0042664297, 'abstract'),
#    (0.0042271414, 'middle'),
#    (0.0039241165, 'east')],
#   0.6317560779752325),
#  ([(0.022502735, 'strains'),
#    (0.016855888, 'analysis'),
#    (0.016509622, 'gene'),
#    (0.013677106, 'species'),
#    (0.013612086, 'sequence'),
#    (0.013247597, 'sequences'),
#    (0.013188862, 'phylogenetic'),
#    (0.01218374, 'isolates'),
#    (0.011982125, 'genes'),
#    (0.0118199745, 'genome'),
#    (0.011130153, 'genetic'),
#    (0.00837514, 'identified'),
#    (0.008049823, 'virus'),
#    (0.007541126, 'two'),
#    (0.0071424386, 'samples'),
#    (0.0068851802, 'isolated'),
#    (0.0068620723, 'nucleotide'),
#    (0.0065790564, 'study'),
#    (0.0065656835, 'different'),
#    (0.0065079904, 'novel')],
#   0.6308413486042717),
#  ([(0.031506617, 'surveillance'),
#    (0.018800657, 'disease'),
#    (0.01877048, 'data'),
#    (0.015994322, 'network'),
#    (0.014034427, 'epidemic'),
#    (0.010410049, 'transmission'),
#    (0.009700053, 'spatial'),
#    (0.0090762805, 'spread'),
#    (0.008985075, 'networks'),
#    (0.008876324, 'based'),
#    (0.0088202255, 'information'),
#    (0.008456236, 'systems'),
#    (0.0075431364, 'infectious'),
#    (0.0074128592, 'control'),
#    (0.006957803, 'dynamics'),
#    (0.006585673, 'diseases'),
#    (0.006343858, 'health'),
#    (0.0062693255, 'epidemiological'),
#    (0.0057122763, 'epidemiology'),
#    (0.005558294, 'cases')],
#   0.6234283808978538),
#  ([(0.040548414, 'covid'),
#    (0.029543718, 'care'),
#    (0.011886132, 'outbreak'),
#    (0.010568655, 'critical'),
#    (0.010119922, 'health'),
#    (0.0100463275, 'number'),
#    (0.009518703, 'pandemic'),
#    (0.009221181, 'patients'),
#    (0.0083622625, 'measures'),
#    (0.0078042527, 'epidemic'),
#    (0.0074499124, 'deaths'),
#    (0.0071799797, 'medical'),
#    (0.007033683, 'hospital'),
#    (0.006682971, 'icu'),
#    (0.0066819172, 'intensive'),
#    (0.006196233, 'interventions'),
#    (0.005626559, 'cases'),
#    (0.0054611596, 'social'),
#    (0.0049828137, 'impact'),
#    (0.004979486, 'based')],
#   0.6218666330807986),
#  ([(0.03416323, 'frameshifting'),
#    (0.024726141, 'ribosomal'),
#    (0.02127532, 'pseudoknot'),
#    (0.019786555, 'prf'),
#    (0.012710405, 'programmed'),
#    (0.012178664, 'base'),
#    (0.012028575, 'rna'),
#    (0.011039855, 'structure'),
#    (0.009026258, 'em'),
#    (0.009006532, 'stem'),
#    (0.0072943904, 'loop'),
#    (0.0071160197, 'pairs'),
#    (0.006660872, 'pseudoknots'),
#    (0.006533202, 'efficiency'),
#    (0.006188823, 'aptamer'),
#    (0.006162488, 'frameshift'),
#    (0.0058756103, 'osteonecrosis'),
#    (0.005141379, 'mrna'),
#    (0.004822889, 'analysis'),
#    (0.0046320995, 'slippery')],
#   0.6146241928912619),
#  ([(0.046660963, 'treatment'),
#    (0.024594843, 'therapy'),
#    (0.018047145, 'antibiotic'),
#    (0.017420558, 'antibiotics'),
#    (0.015990186, 'oral'),
#    (0.013280411, 'acute'),
#    (0.01198873, 'use'),
#    (0.009962063, 'group'),
#    (0.00996009, 'placebo'),
#    (0.008390522, 'common'),
#    (0.008243989, 'treated'),
#    (0.00784551, 'patients'),
#    (0.0063335355, 'randomized'),
#    (0.0063230917, 'clinical'),
#    (0.0062928763, 'controlled'),
#    (0.006189248, 'trial'),
#    (0.0060265614, 'efficacy'),
#    (0.0059920736, 'mg'),
#    (0.0059874123, 'bacterial'),
#    (0.0057055107, 'day')],
#   0.6107039123786548),
#  ([(0.030922784, 'cells'),
#    (0.025220757, 'cell'),
#    (0.021004627, 'infection'),
#    (0.020610275, 'virus'),
#    (0.014522606, 'viral'),
#    (0.0130697675, 'zikv'),
#    (0.012434657, 'entry'),
#    (0.011982704, 'antiviral'),
#    (0.008091518, 'host'),
#    (0.0077852164, 'viruses'),
#    (0.007391016, 'cellular'),
#    (0.007219608, 'epithelial'),
#    (0.0066804276, 'immune'),
#    (0.006596727, 'cholesterol'),
#    (0.0064152386, 'proteins'),
#    (0.006367529, 'receptors'),
#    (0.006162417, 'innate'),
#    (0.005437379, 'autophagy'),
#    (0.005314865, 'ifitm3'),
#    (0.005186677, 'zika')],
#   0.6097085994772786),
#  ([(0.07829161, 'feline'),
#    (0.0461501, 'cats'),
#    (0.035363954, 'fip'),
#    (0.031201772, 'fipv'),
#    (0.025631739, 'peritonitis'),
#    (0.024787946, 'fcov'),
#    (0.022788703, 'infectious'),
#    (0.020521685, 'coronavirus'),
#    (0.01271956, 'type'),
#    (0.010938704, 'fcv'),
#    (0.0098119965, 'cell'),
#    (0.008877598, 'activity'),
#    (0.0085703675, 'abstract'),
#    (0.0077790543, 'infection'),
#    (0.0074391575, 'ii'),
#    (0.00682137, 'fecv'),
#    (0.0066105765, 'disease'),
#    (0.006324027, 'cells'),
#    (0.0060858815, 'virus'),
#    (0.00584672, 'calicivirus')],
#   0.6092391745512178),
#  ([(0.05105725, 'gene'),
#    (0.037363905, 'expression'),
#    (0.025030298, 'genes'),
#    (0.016616652, 'protein'),
#    (0.014752355, 'sign'),
#    (0.014655834, 'dc'),
#    (0.010057774, 'sequence'),
#    (0.009733739, 'expressed'),
#    (0.0089081405, 'analysis'),
#    (0.008445277, 'mrna'),
#    (0.0070949304, 'orf'),
#    (0.0067016515, 'cells'),
#    (0.0065253815, 'lncrnas'),
#    (0.0054960866, 'coding'),
#    (0.005431007, 'proteins'),
#    (0.0050759073, 'transcriptional'),
#    (0.004953274, 'human'),
#    (0.0047180727, 'regulated'),
#    (0.0046676244, 'cell'),
#    (0.0044085253, 'cdna')],
#   0.6030348601683838),
#  ([(0.020871056, 'compounds'),
#    (0.014944666, 'inhibitors'),
#    (0.0136397295, 'drug'),
#    (0.010286365, 'activity'),
#    (0.009591235, 'screening'),
#    (0.009566093, 'drugs'),
#    (0.009158671, 'anti'),
#    (0.00704916, 'based'),
#    (0.006962708, 'potential'),
#    (0.0068692737, 'active'),
#    (0.006789847, 'activities'),
#    (0.006633691, 'used'),
#    (0.006102878, 'target'),
#    (0.005695049, 'discovery'),
#    (0.005440801, 'targets'),
#    (0.005331085, 'antiviral'),
#    (0.004922589, 'chemical'),
#    (0.0048224526, 'small'),
#    (0.0047032996, 'natural'),
#    (0.0046830443, 'abstract')],
#   0.6027671026812345),
#  ([(0.021849863, 'diseases'),
#    (0.021289833, 'disease'),
#    (0.017503342, 'human'),
#    (0.01374145, 'emerging'),
#    (0.01225865, 'infectious'),
#    (0.011746559, 'animal'),
#    (0.010772976, 'virus'),
#    (0.009277715, 'pathogens'),
#    (0.008972324, 'humans'),
#    (0.0083090905, 'zoonotic'),
#    (0.00826055, 'animals'),
#    (0.008073146, 'viruses'),
#    (0.0077051115, 'new'),
#    (0.0076118615, 'species'),
#    (0.0070391456, 'emergence'),
#    (0.006868171, 'transmission'),
#    (0.006671198, 'health'),
#    (0.0057949065, 'infections'),
#    (0.0053676576, 'viral'),
#    (0.004513572, 'outbreaks')],
#   0.602521482495646),
#  ([(0.03745521, 'antiviral'),
#    (0.027491765, 'activity'),
#    (0.023851091, 'virus'),
#    (0.0133491, 'viral'),
#    (0.012548141, 'anti'),
#    (0.010291533, 'replication'),
#    (0.008531725, 'treatment'),
#    (0.008244065, 'vitro'),
#    (0.0077498555, 'compounds'),
#    (0.007386276, 'viruses'),
#    (0.0071537835, 'drug'),
#    (0.006729964, 'drugs'),
#    (0.006667351, 'inhibition'),
#    (0.0065017147, 'effect'),
#    (0.0064876718, 'infection'),
#    (0.006478791, 'cells'),
#    (0.006053571, 'abstract'),
#    (0.005717895, 'effects'),
#    (0.005483898, 'potent'),
#    (0.0053672767, 'effective')],
#   0.6011878111354503),
#  ([(0.019992545, 'ci'),
#    (0.01685347, 'patients'),
#    (0.016147677, 'study'),
#    (0.01415382, 'risk'),
#    (0.00942358, 'among'),
#    (0.008604457, 'associated'),
#    (0.007999528, 'factors'),
#    (0.007677455, 'results'),
#    (0.007608458, 'participants'),
#    (0.0073727933, 'symptoms'),
#    (0.0061083417, 'emergency'),
#    (0.0059051383, 'ed'),
#    (0.0058224187, 'influenza'),
#    (0.0056958934, 'methods'),
#    (0.005652238, 'infection'),
#    (0.005632647, 'hospital'),
#    (0.0052291355, 'respiratory'),
#    (0.005098953, 'hcws'),
#    (0.0049732286, 'years'),
#    (0.0049598673, 'age')],
#   0.6005332069447962),
#  ([(0.01389307, 'development'),
#    (0.010887319, 'based'),
#    (0.010090733, 'delivery'),
#    (0.01005432, 'applications'),
#    (0.00940734, 'review'),
#    (0.009041597, 'drug'),
#    (0.00851288, 'new'),
#    (0.008389639, 'production'),
#    (0.008285909, 'vaccines'),
#    (0.008185971, 'use'),
#    (0.007431288, 'systems'),
#    (0.00706412, 'plant'),
#    (0.007021623, 'technologies'),
#    (0.0064388704, 'technology'),
#    (0.0064012166, 'therapeutic'),
#    (0.0063114217, 'recent'),
#    (0.0062060095, 'potential'),
#    (0.005833324, 'clinical'),
#    (0.005049409, 'advances'),
#    (0.004901479, 'human')],
#   0.6004093784019028),
#  ([(0.03398972, 'immune'),
#    (0.026646366, 'host'),
#    (0.018100178, 'response'),
#    (0.014403089, 'immunity'),
#    (0.013250257, 'innate'),
#    (0.011871138, 'responses'),
#    (0.0108849155, 'pathogen'),
#    (0.01059768, 'pathogens'),
#    (0.007532375, 'system'),
#    (0.007433893, 'vaccines'),
#    (0.00743219, 'review'),
#    (0.0073288917, 'development'),
#    (0.0071515203, 'adaptive'),
#    (0.0071151615, 'infection'),
#    (0.0063954974, 'mechanisms'),
#    (0.0062147058, 'understanding'),
#    (0.0057308767, 'disease'),
#    (0.0054920786, 'vaccine'),
#    (0.0054706945, 'interactions'),
#    (0.0053420677, 'viral')],
#   0.5982065549407858),
#  ([(0.01710024, 'number'),
#    (0.015920846, 'model'),
#    (0.0126408925, 'epidemic'),
#    (0.012332625, 'disease'),
#    (0.011679014, 'cases'),
#    (0.009659089, 'outbreak'),
#    (0.009614597, 'reproduction'),
#    (0.009529385, 'quarantine'),
#    (0.008713049, 'outbreaks'),
#    (0.008663446, 'incidence'),
#    (0.008435516, 'influenza'),
#    (0.008429339, 'control'),
#    (0.008304186, 'time'),
#    (0.0076347683, 'data'),
#    (0.0069705276, 'using'),
#    (0.0068403664, 'transmission'),
#    (0.006763423, 'estimate'),
#    (0.006738253, 'estimates'),
#    (0.0059344093, 'screening'),
#    (0.0055165645, 'population')],
#   0.5965178708784419),
#  ([(0.07125201, 'il'),
#    (0.019488562, 'inflammatory'),
#    (0.019133925, 'cytokine'),
#    (0.01800071, 'cytokines'),
#    (0.016984072, 'levels'),
#    (0.012607381, 'rv'),
#    (0.010655443, 'infection'),
#    (0.010278537, 'interleukin'),
#    (0.008106992, 'tnf'),
#    (0.0073055765, 'response'),
#    (0.0071171275, 'patients'),
#    (0.0069052125, 'increased'),
#    (0.0067956354, 'disease'),
#    (0.006654706, '1β'),
#    (0.0066525843, 'induced'),
#    (0.0065081436, 'immune'),
#    (0.006485093, 'expression'),
#    (0.0063801683, 'acute'),
#    (0.006274735, 'associated'),
#    (0.006060341, 'cells')],
#   0.5936898097117536),
#  ([(0.052762818, 'protein'),
#    (0.023869803, 'receptor'),
#    (0.018434342, 'coronavirus'),
#    (0.017625675, 'spike'),
#    (0.01596271, 'binding'),
#    (0.01576451, 'host'),
#    (0.012442972, 'coronaviruses'),
#    (0.00976624, 'viral'),
#    (0.009343794, 'family'),
#    (0.008964148, 'proteins'),
#    (0.008724119, 'human'),
#    (0.0076410095, 'viruses'),
#    (0.0072928416, 'nucleocapsid'),
#    (0.0064298487, 'domain'),
#    (0.006344562, 'virus'),
#    (0.0062121986, 'interaction'),
#    (0.0060753473, 'species'),
#    (0.0053293216, 'structural'),
#    (0.0052585895, 'respiratory'),
#    (0.004826737, 'evolution')],
#   0.5891174319911469),
#  ([(0.040293194, 'air'),
#    (0.013712531, 'airborne'),
#    (0.012481073, 'ventilation'),
#    (0.008558791, 'indoor'),
#    (0.007279867, 'abstract'),
#    (0.0068532117, 'environmental'),
#    (0.006818036, 'transport'),
#    (0.0066956514, 'study'),
#    (0.0065517644, 'exposure'),
#    (0.005865418, 'pollution'),
#    (0.005297177, 'environment'),
#    (0.0047708713, 'temperature'),
#    (0.004764876, 'particle'),
#    (0.0046547144, 'effects'),
#    (0.004616359, 'dispersion'),
#    (0.0045753545, 'quality'),
#    (0.004541389, 'transmission'),
#    (0.004451549, 'system'),
#    (0.0044503785, 'climate'),
#    (0.004409228, 'room')],
#   0.5705923679476553),
#  ([(0.032155376, 'patients'),
#    (0.027573438, 'respiratory'),
#    (0.024000494, 'influenza'),
#    (0.013409845, 'children'),
#    (0.013130242, 'viruses'),
#    (0.012761239, 'virus'),
#    (0.011010532, 'study'),
#    (0.008864011, 'years'),
#    (0.008714538, 'infection'),
#    (0.008641356, 'age'),
#    (0.008235695, 'infections'),
#    (0.008081961, 'results'),
#    (0.008023718, 'positive'),
#    (0.0075340713, 'viral'),
#    (0.007349741, 'acute'),
#    (0.006912109, 'clinical'),
#    (0.0067719887, 'detected'),
#    (0.006652295, 'among'),
#    (0.0065255156, 'associated'),
#    (0.006223155, 'cases')],
#   0.5664297246884846),
#  ([(0.052410815, 'pneumonia'),
#    (0.025127074, 'patients'),
#    (0.019879403, 'cap'),
#    (0.014825686, 'acquired'),
#    (0.01408005, 'clinical'),
#    (0.01179697, 'community'),
#    (0.011448521, 'ct'),
#    (0.009532948, 'diagnosis'),
#    (0.009183943, 'sepsis'),
#    (0.0090130055, 'chest'),
#    (0.008901806, 'group'),
#    (0.008396301, 'diagnostic'),
#    (0.007955689, 'mortality'),
#    (0.007925468, 'hla'),
#    (0.0069983024, 'disease'),
#    (0.0067828866, 'lung'),
#    (0.006001541, 'severe'),
#    (0.0058603045, 'atypical'),
#    (0.005806654, 'pneumoniae'),
#    (0.0054535335, 'imaging')],
#   0.566425022908266),
#  ([(0.022574505, 'model'),
#    (0.015977839, 'epidemic'),
#    (0.011376266, 'population'),
#    (0.010054313, 'models'),
#    (0.009910701, 'number'),
#    (0.009158255, 'time'),
#    (0.009051606, 'transmission'),
#    (0.009031817, 'dynamics'),
#    (0.00879741, 'data'),
#    (0.008458273, 'disease'),
#    (0.0083105825, 'contact'),
#    (0.00828835, 'spread'),
#    (0.0078090047, 'individuals'),
#    (0.0074554044, 'rate'),
#    (0.0074169757, 'infected'),
#    (0.007004469, 'growth'),
#    (0.005787956, 'infection'),
#    (0.00567633, 'epidemics'),
#    (0.005493029, 'parameters'),
#    (0.005436098, 'covid')],
#   0.5660284068823265),
#  ([(0.045044888, 'virus'),
#    (0.017391581, 'ibv'),
#    (0.017194672, 'mhv'),
#    (0.015881442, 'cells'),
#    (0.015648458, 'strain'),
#    (0.01179279, 'cell'),
#    (0.0116743175, 'protein'),
#    (0.01022944, 'infectious'),
#    (0.010154769, 'strains'),
#    (0.009096325, 'coronavirus'),
#    (0.007760699, 'bronchitis'),
#    (0.007347672, 'mouse'),
#    (0.007050408, 'recombinant'),
#    (0.00667913, 'infection'),
#    (0.006140395, 'abstract'),
#    (0.006003443, 'infected'),
#    (0.0058782226, 'type'),
#    (0.0056633335, 's1'),
#    (0.0053164405, 'hepatitis'),
#    (0.0052275555, 'viruses')],
#   0.565236366501079),
#  ([(0.028002402, 'genes'),
#    (0.023522079, 'associated'),
#    (0.016965887, 'polymorphisms'),
#    (0.01491086, 'gene'),
#    (0.0144986175, 'susceptibility'),
#    (0.014023196, 'association'),
#    (0.012706366, 'patients'),
#    (0.0112646455, 'snps'),
#    (0.010788402, 'genetic'),
#    (0.010148158, 'allele'),
#    (0.009650343, 'polymorphism'),
#    (0.009502253, 'expression'),
#    (0.009443586, 'variants'),
#    (0.0092758965, 'infection'),
#    (0.009078091, 'controls'),
#    (0.008993592, 'genotype'),
#    (0.008711326, 'risk'),
#    (0.007643838, 'analysis'),
#    (0.0072282366, 'disease'),
#    (0.0071808035, 'significantly')],
#   0.5586186529478105),
#  ([(0.044158578, 'viruses'),
#    (0.026686352, 'viral'),
#    (0.01864142, 'virus'),
#    (0.012868397, 'sequencing'),
#    (0.012837107, 'host'),
#    (0.010452757, 'genome'),
#    (0.0075131953, 'genomes'),
#    (0.007121266, 'human'),
#    (0.0069465945, 'species'),
#    (0.0068098856, 'novel'),
#    (0.0059855008, 'evolution'),
#    (0.0055054347, 'new'),
#    (0.005390224, 'diversity'),
#    (0.0048656287, 'high'),
#    (0.0044047395, 'rna'),
#    (0.0042613163, 'also'),
#    (0.004174699, 'known'),
#    (0.0040327227, 'identification'),
#    (0.0039212657, 'analysis'),
#    (0.0038567453, 'sequences')],
#   0.558095174108743),
#  ([(0.07791923, 'hiv'),
#    (0.018439054, 'protein'),
#    (0.01172481, 'domain'),
#    (0.01021008, 'site'),
#    (0.009009954, 'type'),
#    (0.008953281, 'activity'),
#    (0.008920705, 'er'),
#    (0.008671998, 'signal'),
#    (0.008227638, 'terminal'),
#    (0.008147838, 'proteins'),
#    (0.0076865917, 'amino'),
#    (0.0075239693, 'immunodeficiency'),
#    (0.0073117735, 'frameshifting'),
#    (0.00727807, 'binding'),
#    (0.0072298753, 'sequence'),
#    (0.0071863257, 'gag'),
#    (0.006722912, 'two'),
#    (0.0062776906, 'lectin'),
#    (0.005825903, 'frameshift'),
#    (0.005643015, 'transmembrane')],
#   0.5577962597508828),
#  ([(0.1104544, 'hcov'),
#    (0.06637939, 'human'),
#    (0.050202433, '229e'),
#    (0.049072385, 'oc43'),
#    (0.045266964, 'coronavirus'),
#    (0.044979498, 'nl63'),
#    (0.030993657, 'coronaviruses'),
#    (0.026156614, 'hku1'),
#    (0.014730557, 'hcovs'),
#    (0.011381953, 'respiratory'),
#    (0.0071298387, 'infection'),
#    (0.0060644, 'protein'),
#    (0.0054747164, 'patients'),
#    (0.0053594313, 'tract'),
#    (0.005220746, 'cold'),
#    (0.005049611, 'common'),
#    (0.004972481, 'hcv'),
#    (0.004852036, 'bile'),
#    (0.0046991673, 'associated'),
#    (0.0046349866, 'infections')],
#   0.5523259171387146),
#  ([(0.0455099, 'canine'),
#    (0.03543941, 'dogs'),
#    (0.023293236, 'virus'),
#    (0.01840272, 'clinical'),
#    (0.015188222, 'infections'),
#    (0.013884229, 'cdv'),
#    (0.013881551, 'infection'),
#    (0.0130702425, 'respiratory'),
#    (0.01211873, 'disease'),
#    (0.010610073, 'diagnosis'),
#    (0.009888221, 'crcov'),
#    (0.009597446, 'distemper'),
#    (0.008896478, 'dog'),
#    (0.008717443, 'infectious'),
#    (0.0080483155, 'coronavirus'),
#    (0.0077987835, 'laboratory'),
#    (0.0071796407, 'viral'),
#    (0.007153857, 'diagnostic'),
#    (0.006404082, 'pathogens'),
#    (0.005032035, 'associated')],
#   0.5456374429917888),
#  ([(0.023184218, 'tb'),
#    (0.02081713, 'dengue'),
#    (0.017399361, 'malaria'),
#    (0.016903821, 'tuberculosis'),
#    (0.01528815, 'articles'),
#    (0.01292676, 'research'),
#    (0.010663353, 'countries'),
#    (0.010611815, 'published'),
#    (0.007915498, 'literature'),
#    (0.007889465, 'travel'),
#    (0.0068174168, 'review'),
#    (0.0066152485, 'publications'),
#    (0.005781416, 'search'),
#    (0.005704658, 'study'),
#    (0.005295282, 'analysis'),
#    (0.0052663414, 'papers'),
#    (0.0049945745, 'results'),
#    (0.0046634115, 'related'),
#    (0.004623439, 'trends'),
#    (0.0046084085, 'information')],
#   0.5448395996834152),
#  ([(0.018488461, 'immune'),
#    (0.0168022, 'viral'),
#    (0.013039755, 'infections'),
#    (0.012960155, 'may'),
#    (0.012100202, 'infection'),
#    (0.011097268, 'disease'),
#    (0.010262043, 'virus'),
#    (0.010103221, 'host'),
#    (0.008950179, 'lung'),
#    (0.00891996, 'mechanisms'),
#    (0.0084084235, 'pathogenesis'),
#    (0.008171092, 'cells'),
#    (0.0077572707, 'role'),
#    (0.0074132998, 'respiratory'),
#    (0.0071604974, 'viruses'),
#    (0.0071131224, 'factors'),
#    (0.00669546, 'response'),
#    (0.006654159, 'inflammatory'),
#    (0.005890347, 'responses'),
#    (0.005735423, 'inflammation')],
#   0.5282686886476767),
#  ([(0.052145418, 'infection'),
#    (0.048025772, 'mice'),
#    (0.021341043, 'lung'),
#    (0.014223702, 'infected'),
#    (0.010365598, 'alveolar'),
#    (0.009538521, 'lungs'),
#    (0.009531813, 'virus'),
#    (0.009325966, 'mouse'),
#    (0.008696456, 'golgi'),
#    (0.008489996, 'model'),
#    (0.007170993, 'acute'),
#    (0.0069987727, 'severe'),
#    (0.0061628353, 'tissue'),
#    (0.0059642447, 'disease'),
#    (0.0057870657, 'pulmonary'),
#    (0.0057495194, 'cells'),
#    (0.0056179184, 'pathology'),
#    (0.00507493, 'respiratory'),
#    (0.0046806503, 'observed'),
#    (0.0044351746, 'damage')],
#   0.5234500273428286),
#  ([(0.030247252, 'cats'),
#    (0.020511525, 'dogs'),
#    (0.014437585, 'cpv'),
#    (0.012511181, 'infection'),
#    (0.012317352, 'pcv2'),
#    (0.011895579, 'pigs'),
#    (0.01044154, 'feline'),
#    (0.0103250155, 'canine'),
#    (0.0102099, 'samples'),
#    (0.0098188585, 'fiv'),
#    (0.008528196, 'virus'),
#    (0.008404497, 'study'),
#    (0.008107588, 'parvovirus'),
#    (0.008037723, 'infected'),
#    (0.00793623, 'positive'),
#    (0.0072871028, 'detected'),
#    (0.006499506, 'type'),
#    (0.006435679, 'clinical'),
#    (0.0061222264, 'cat'),
#    (0.0058655357, 'animals')],
#   0.5203575015093186),
#  ([(0.105093546, 'influenza'),
#    (0.024715785, 'pandemic'),
#    (0.021260085, 'virus'),
#    (0.017015247, 'h1n1'),
#    (0.015229831, 'infections'),
#    (0.01433778, 'respiratory'),
#    (0.011963354, 'seasonal'),
#    (0.011616411, 'flu'),
#    (0.011542944, 'viruses'),
#    (0.010642729, 'disease'),
#    (0.00855426, 'viral'),
#    (0.008413116, 'swine'),
#    (0.006611909, 'infection'),
#    (0.0054752487, 'surfaces'),
#    (0.0054144454, 'avian'),
#    (0.00538594, 'may'),
#    (0.005009003, 'transmission'),
#    (0.004658477, 'management'),
#    (0.0044228146, 'disinfection'),
#    (0.004418693, 'human')],
#   0.5184188756847651),
#  ([(0.039634228, 'research'),
#    (0.011176742, 'hev'),
#    (0.010259845, 'biology'),
#    (0.010192174, 'review'),
#    (0.00884737, 'nucleic'),
#    (0.008219824, 'human'),
#    (0.007762827, 'development'),
#    (0.0076571917, 'progress'),
#    (0.0063975905, 'biological'),
#    (0.0063343537, 'recent'),
#    (0.006114267, 'new'),
#    (0.005942218, 'years'),
#    (0.0053060506, 'science'),
#    (0.0052393214, 'molecular'),
#    (0.0050362945, 'also'),
#    (0.0050102295, 'knowledge'),
#    (0.0049407245, 'many'),
#    (0.0049011037, 'scientific'),
#    (0.0048856796, 'overview'),
#    (0.004836898, 'acid')],
#   0.5149745867985337),
#  ([(0.017426293, 'dna'),
#    (0.017226106, 'binding'),
#    (0.017167112, 'lamp'),
#    (0.0135010155, 'surface'),
#    (0.0109389685, 'ndv'),
#    (0.010745541, 'loop'),
#    (0.0086487075, 'based'),
#    (0.008444366, 'amplification'),
#    (0.008157594, 'fluorescence'),
#    (0.008073426, 'using'),
#    (0.007544829, 'detection'),
#    (0.007235425, 'acid'),
#    (0.0070801573, 'isothermal'),
#    (0.00608232, 'high'),
#    (0.0055778017, 'temperature'),
#    (0.0054003177, 'sensor'),
#    (0.0051943185, 'chip'),
#    (0.0051866667, 'mediated'),
#    (0.0049653426, 'simple'),
#    (0.004822943, 'resonance')],
#   0.5144140249841505),
#  ([(0.048068743, 'avian'),
#    (0.02865833, 'virus'),
#    (0.023664365, 'poultry'),
#    (0.023319483, 'birds'),
#    (0.023230916, 'viruses'),
#    (0.02304941, 'turkey'),
#    (0.02079865, 'h7n9'),
#    (0.01340848, 'tcov'),
#    (0.01178433, 'aiv'),
#    (0.010318029, 'wild'),
#    (0.009389404, 'chicken'),
#    (0.008884292, 'viral'),
#    (0.00880976, 'influenza'),
#    (0.008624803, 'samples'),
#    (0.008578281, 'gastroenteritis'),
#    (0.008467248, 'chickens'),
#    (0.008062881, 'disease'),
#    (0.0075594983, 'detected'),
#    (0.0075455513, 'coronavirus'),
#    (0.0072657634, 'flocks')],
#   0.5114748471551943),
#  ([(0.040028885, 'diseases'),
#    (0.017781187, 'infectious'),
#    (0.015074495, 'review'),
#    (0.011586246, 'disease'),
#    (0.010480604, 'immune'),
#    (0.00949188, 'role'),
#    (0.009113561, 'bacterial'),
#    (0.008357418, 'functions'),
#    (0.008265169, 'recent'),
#    (0.0078092306, 'viral'),
#    (0.0076466384, 'microbial'),
#    (0.007425677, 'various'),
#    (0.0067567006, 'development'),
#    (0.0067191906, 'potential'),
#    (0.006486053, 'therapeutic'),
#    (0.0064519746, 'important'),
#    (0.006177882, 'roles'),
#    (0.0059513752, 'abstract'),
#    (0.00582421, 'infections'),
#    (0.0055394927, 'many')],
#   0.5003648211594898),
#  ([(0.028615087, 'studies'),
#    (0.01896658, 'clinical'),
#    (0.014952249, 'review'),
#    (0.01249705, 'systematic'),
#    (0.009269841, 'evidence'),
#    (0.009175339, 'trials'),
#    (0.008099391, 'treatment'),
#    (0.007578846, 'chinese'),
#    (0.007551464, 'results'),
#    (0.0075307502, 'meta'),
#    (0.0073149526, 'data'),
#    (0.0070862984, 'analysis'),
#    (0.006862145, 'patients'),
#    (0.0067359963, 'used'),
#    (0.006463976, 'medicine'),
#    (0.0062839934, 'literature'),
#    (0.006248994, 'methods'),
#    (0.006152261, 'disease'),
#    (0.0059667653, 'based'),
#    (0.0054971008, 'included')],
#   0.4996544196631286),
#  ([(0.06959776, 'prrsv'),
#    (0.047711436, 'proteins'),
#    (0.030253012, 'reproductive'),
#    (0.0215826, 'porcine'),
#    (0.020621097, 'syndrome'),
#    (0.020548157, 'virus'),
#    (0.020014161, 'protein'),
#    (0.019138921, 'respiratory'),
#    (0.008174702, 'prrs'),
#    (0.007126371, 'proteomic'),
#    (0.007069377, 'viral'),
#    (0.006988175, 'study'),
#    (0.0066497275, 'identified'),
#    (0.006307811, 'analysis'),
#    (0.006162867, 'swine'),
#    (0.006016803, 'host'),
#    (0.005457782, 'infected'),
#    (0.005334179, 'cellular'),
#    (0.005183069, 'replication'),
#    (0.0050693783, 'proteomics')],
#   0.4966143919102512),
#  ([(0.057423722, 'ifn'),
#    (0.044639386, 'type'),
#    (0.0267123, 'hadv'),
#    (0.016123401, 'ms'),
#    (0.015500057, 'interferon'),
#    (0.011515919, 'ifns'),
#    (0.010183597, 'cells'),
#    (0.009443181, 'interferons'),
#    (0.009243492, 'patients'),
#    (0.0082989065, 'human'),
#    (0.008214077, 'viral'),
#    (0.008154803, 'microglia'),
#    (0.007930112, 'iii'),
#    (0.007442283, 'infection'),
#    (0.0070838574, 'response'),
#    (0.006554488, 'cell'),
#    (0.006340022, 'ccr5'),
#    (0.0058480776, 'isgs'),
#    (0.0051493514, 'stat1'),
#    (0.0051364587, 'macrophages')],
#   0.48346047515438634),
#  ([(0.048121575, 'class'),
#    (0.03794247, 'mhc'),
#    (0.02322968, 'ii'),
#    (0.01851064, 'e2'),
#    (0.016408581, 'cell'),
#    (0.014947484, 'complex'),
#    (0.013652534, 'cells'),
#    (0.011797335, 'antigen'),
#    (0.011634396, 'e1'),
#    (0.010890655, 'histocompatibility'),
#    (0.009950119, 'major'),
#    (0.009925159, 'molecules'),
#    (0.008998422, 'antigens'),
#    (0.008890299, 'hla'),
#    (0.00886379, 'alleles'),
#    (0.008160265, 'rat'),
#    (0.0077874893, 'rats'),
#    (0.0065049003, 'retinal'),
#    (0.0062340074, 'env'),
#    (0.0047404016, 'present')],
#   0.4788155667929693),
#  ([(0.021797996, 'model'),
#    (0.018149568, 'data'),
#    (0.013049065, 'models'),
#    (0.009117655, 'based'),
#    (0.008316839, 'using'),
#    (0.0075289193, 'used'),
#    (0.007305397, 'method'),
#    (0.0068608257, 'disease'),
#    (0.006763478, 'network'),
#    (0.006497191, 'information'),
#    (0.006436814, 'approach'),
#    (0.006356222, 'time'),
#    (0.005992377, 'analysis'),
#    (0.0055937925, 'results'),
#    (0.0051194183, 'proposed'),
#    (0.00511091, 'learning'),
#    (0.0049466053, 'abstract'),
#    (0.0047225785, 'study'),
#    (0.004679169, 'methods'),
#    (0.0046138456, 'accuracy')],
#   0.4726159690472941),
#  ([(0.06614387, 'ebola'),
#    (0.024822026, 'virus'),
#    (0.022456141, 'management'),
#    (0.022119898, 'ebov'),
#    (0.018877463, 'disease'),
#    (0.018666662, 'evd'),
#    (0.012149211, 'hcv'),
#    (0.011552848, 'infection'),
#    (0.01140178, 'west'),
#    (0.010940924, 'africa'),
#    (0.009966868, 'infectious'),
#    (0.008717567, 'patients'),
#    (0.008532588, 'outbreak'),
#    (0.0074513475, 'care'),
#    (0.0068425396, 'biosecurity'),
#    (0.006551028, 'guinea'),
#    (0.006487496, 'diseases'),
#    (0.006413148, 'risk'),
#    (0.0061147697, 'control'),
#    (0.0056194332, 'transmission')],
#   0.47132716443283085),
#  ([(0.014799585, 'stress'),
#    (0.009321752, 'oxidative'),
#    (0.008668954, 'activity'),
#    (0.008046221, 'acid'),
#    (0.008015449, 'oxide'),
#    (0.0064909463, 'metal'),
#    (0.0060025537, 'acids'),
#    (0.005908533, 'reaction'),
#    (0.005495271, 'antioxidant'),
#    (0.0053014485, 'abstract'),
#    (0.0052944114, 'enzyme'),
#    (0.0052354583, 'oxygen'),
#    (0.005116205, 'reactive'),
#    (0.0050943024, 'effects'),
#    (0.0047227386, 'complexes'),
#    (0.00460654, 'fatty'),
#    (0.004573875, 'release'),
#    (0.0045735473, 'effect'),
#    (0.0045704064, 'increased'),
#    (0.0045602513, 'properties')],
#   0.4647037881577402),
#  ([(0.013144645, 'liquid'),
#    (0.011157307, 'concentration'),
#    (0.010580258, 'uv'),
#    (0.010463348, 'extraction'),
#    (0.009991198, 'sampling'),
#    (0.009384665, 'aerosol'),
#    (0.0091131115, 'chromatography'),
#    (0.008676143, 'efficiency'),
#    (0.008355469, 'study'),
#    (0.008258351, 'phase'),
#    (0.007963511, 'used'),
#    (0.0078014648, 'method'),
#    (0.0070209783, 'using'),
#    (0.0068958616, 'mass'),
#    (0.006809664, 'separation'),
#    (0.006799054, 'aerosols'),
#    (0.0064170873, 'glycyrrhizin'),
#    (0.0061565014, 'high'),
#    (0.006042439, 'particles'),
#    (0.0060308576, 'acid')],
#   0.458733585311244),
#  ([(0.06281856, 'influenza'),
#    (0.035688482, 'virus'),
#    (0.026015984, 'viruses'),
#    (0.015538366, 'ha'),
#    (0.01380368, 'human'),
#    (0.012123697, 'supplementary'),
#    (0.0117374, 'viral'),
#    (0.010701226, 'h1n1'),
#    (0.009816899, 'host'),
#    (0.009612682, 'material'),
#    (0.009567916, 'avian'),
#    (0.008231031, 'hemagglutinin'),
#    (0.008224485, 'iav'),
#    (0.007614317, 'h5n1'),
#    (0.0072671487, 'like'),
#    (0.006828398, 'vlps'),
#    (0.0067326785, 'na'),
#    (0.00616344, 'authorized'),
#    (0.005707033, 'h3n2'),
#    (0.0056394567, 'users')],
#   0.45039392889577884),
#  ([(0.06213219, 'blood'),
#    (0.023728989, 'plasma'),
#    (0.017264435, 'transfusion'),
#    (0.015673442, 'inactivation'),
#    (0.008433413, 'contamination'),
#    (0.008100319, 'safety'),
#    (0.0074140076, 'testing'),
#    (0.00693997, 'infection'),
#    (0.0068758195, 'risk'),
#    (0.0067704697, 'products'),
#    (0.0067300326, 'patients'),
#    (0.006219536, 'dental'),
#    (0.006177183, 'procedures'),
#    (0.006164496, 'guidelines'),
#    (0.0054859435, 'methods'),
#    (0.0053791907, 'evidence'),
#    (0.005304749, 'screening'),
#    (0.0046111927, 'red'),
#    (0.004598822, 'donors'),
#    (0.0045039486, 'removal')],
#   0.4413482104034253),
#  ([(0.02542486, 'resistant'),
#    (0.021701064, 'antimicrobial'),
#    (0.021642407, 'water'),
#    (0.018970383, 'resistance'),
#    (0.018073969, 'aureus'),
#    (0.013465967, 'staphylococcus'),
#    (0.013213443, 'bacteria'),
#    (0.011673819, 'mrsa'),
#    (0.0074994126, 'taiwan'),
#    (0.0063067162, 'bacterial'),
#    (0.0059086434, 'study'),
#    (0.0058401288, 'use'),
#    (0.0056028776, 'gram'),
#    (0.005097513, 'used'),
#    (0.0050762263, 'wastewater'),
#    (0.0048414166, 'abstract'),
#    (0.0046821884, 'health'),
#    (0.0045383573, 'isolates'),
#    (0.0044499305, 'methicillin'),
#    (0.0044339146, 'consumption')],
#   0.4375168763483493),
#  ([(0.014939687, 'zinc'),
#    (0.014502298, 'secretory'),
#    (0.011912004, 'und'),
#    (0.011733905, 'die'),
#    (0.01003445, 'der'),
#    (0.009879353, 'mr'),
#    (0.009477704, 'rats'),
#    (0.007696661, 'ptsd'),
#    (0.0074737584, 'nutrition'),
#    (0.006680099, 'cp'),
#    (0.006486143, 'mammary'),
#    (0.0063719857, 'protein'),
#    (0.0058530373, 'pcv'),
#    (0.005806253, 'zn'),
#    (0.005764119, 'mt'),
#    (0.0056900894, 'gland'),
#    (0.0056207036, 'high'),
#    (0.0055372114, 'diet'),
#    (0.005508465, 'nutritional'),
#    (0.0054300143, 'von')],
#   0.4253827112003292),
#  ([(0.010409952, 'lymph'),
#    (0.008484347, 'cells'),
#    (0.008392671, 'cats'),
#    (0.008241564, 'bcov'),
#    (0.007973432, 'cat'),
#    (0.0064046574, 'cell'),
#    (0.006334015, 'revealed'),
#    (0.006305934, 'nodes'),
#    (0.00606113, 'blood'),
#    (0.005910244, 'associated'),
#    (0.0056302277, 'acid'),
#    (0.0055571864, 'isolates'),
#    (0.005433278, 'study'),
#    (0.005091909, 'feline'),
#    (0.0048605977, 'bovine'),
#    (0.0047337534, 'tissues'),
#    (0.0046777977, 'gene'),
#    (0.004618207, 'coronavirus'),
#    (0.0044761584, 'samples'),
#    (0.0042864406, 'two')],
#   0.42348424460570755),
#  ([(0.04988378, 'disaster'),
#    (0.026216462, 'helicase'),
#    (0.025307084, 'droplets'),
#    (0.01795894, 'droplet'),
#    (0.017787777, 'cough'),
#    (0.017182717, 'coughing'),
#    (0.012525651, 'sodium'),
#    (0.009566297, 'respiratory'),
#    (0.008682079, 'disinfectants'),
#    (0.0076521575, 'infection'),
#    (0.0073534395, 'transmission'),
#    (0.007241614, 'sf'),
#    (0.006856832, 'sneezing'),
#    (0.006739722, 'aerosol'),
#    (0.006457372, 'particles'),
#    (0.0059188805, 'facial'),
#    (0.0058809514, 'size'),
#    (0.0057068276, 'ntpase'),
#    (0.0056968336, 'listeria'),
#    (0.0053736065, 'results')],
#   0.41004006012200805),
#  ([(0.051377334, 'denv'),
#    (0.048723634, 'ccov'),
#    (0.03065212, 'norovirus'),
#    (0.017530007, 'ocular'),
#    (0.015567029, 'dengue'),
#    (0.014795923, 'gi'),
#    (0.013682996, 'canine'),
#    (0.011722405, 'gastrointestinal'),
#    (0.009755401, 'gii'),
#    (0.009089777, 'ibd'),
#    (0.008956482, 'exhaled'),
#    (0.008933632, 'hi'),
#    (0.008367898, 'intensity'),
#    (0.00827556, 'prion'),
#    (0.008116243, 'ii'),
#    (0.007981744, 'strains'),
#    (0.0070512113, 'mnv'),
#    (0.0070379307, 'carbon'),
#    (0.006816117, 'diseases'),
#    (0.0067105344, 'strain')],
#   0.40750971712994294),
#  ([(0.030207966, 'protein'),
#    (0.011803943, 'proteins'),
#    (0.008940414, 'based'),
#    (0.007334131, 'using'),
#    (0.007233574, 'sequence'),
#    (0.0069353045, 'peptide'),
#    (0.0063418816, 'analysis'),
#    (0.0062012495, 'sequences'),
#    (0.006015905, 'used'),
#    (0.005771447, 'peptides'),
#    (0.005760432, 'cell'),
#    (0.0057482384, 'method'),
#    (0.005682674, 'expression'),
#    (0.004688714, 'high'),
#    (0.004463242, 'approach'),
#    (0.004408769, 'recombinant'),
#    (0.004322025, 'methods'),
#    (0.004300303, 'new'),
#    (0.0036655485, 'results'),
#    (0.0034335253, 'prediction')],
#   0.4074452367726387),
#  ([(0.03290222, 'codon'),
#    (0.032368086, 'usage'),
#    (0.028808534, 'transplantation'),
#    (0.020900367, 'transplant'),
#    (0.020472188, 'stem'),
#    (0.019727817, 'measles'),
#    (0.018581068, 'recipients'),
#    (0.014814739, 'cell'),
#    (0.0131761255, 'hematopoietic'),
#    (0.012928492, 'patients'),
#    (0.01171379, 'bias'),
#    (0.011069996, 'organ'),
#    (0.0096744, 'hsct'),
#    (0.008559692, 'donor'),
#    (0.008317194, 'synonymous'),
#    (0.008134757, 'allogeneic'),
#    (0.0072649103, 'graft'),
#    (0.006068412, 'virus'),
#    (0.005748781, 'patterns'),
#    (0.005530666, 'complications')],
#   0.4056491155535372),
#  ([(0.026489872, 'ibv'),
#    (0.012789322, 'bronchitis'),
#    (0.012254837, 'chickens'),
#    (0.012158791, 'infectious'),
#    (0.010847255, 'infection'),
#    (0.010771444, 'lesions'),
#    (0.010750181, 'cells'),
#    (0.010324959, 'disease'),
#    (0.009382058, 'group'),
#    (0.009371572, 'rats'),
#    (0.0092663085, 'virus'),
#    (0.0076074842, 'cd8'),
#    (0.0073048174, 'cd4'),
#    (0.006734752, 'lymphocytes'),
#    (0.005964029, 'chicken'),
#    (0.005817425, 'cell'),
#    (0.005046655, 'results'),
#    (0.0050413064, 'blood'),
#    (0.004909095, 'groups'),
#    (0.004853359, 'viral')],
#   0.40101007522737675),
#  ([(0.023344595, 'cf'),
#    (0.022117382, 'electron'),
#    (0.021360148, 'structure'),
#    (0.017632099, 'microscopy'),
#    (0.013019364, 'exosomes'),
#    (0.01228554, 'structures'),
#    (0.011650201, 'secondary'),
#    (0.011299441, 'em'),
#    (0.011050109, 'rna'),
#    (0.009342508, 'cystic'),
#    (0.008416994, 'ab'),
#    (0.007407336, 'thin'),
#    (0.0073521435, 'fibrosis'),
#    (0.006577554, 'cryo'),
#    (0.005099216, 'localization'),
#    (0.004720055, 'tgn'),
#    (0.0044990154, 'prediction'),
#    (0.0044530826, 'pseudoknot'),
#    (0.0043218355, 'pdr'),
#    (0.0042668507, 'exosome')],
#   0.38176768628055646),
#  ([(0.054776087, 'patients'),
#    (0.009529704, 'function'),
#    (0.0095280465, 'group'),
#    (0.008043619, 'exercise'),
#    (0.008008586, 'disease'),
#    (0.007955192, 'study'),
#    (0.006473808, 'patient'),
#    (0.006165938, 'significant'),
#    (0.0061576897, 'lung'),
#    (0.005979146, 'post'),
#    (0.0058465158, 'non'),
#    (0.0056988406, 'sleep'),
#    (0.0053045605, 'stress'),
#    (0.005225028, 'isolation'),
#    (0.0049971105, 'treatment'),
#    (0.0049372236, 'results'),
#    (0.0047558895, 'survivors'),
#    (0.004661898, 'significantly'),
#    (0.0046522445, 'months'),
#    (0.0044670897, 'related')],
#   0.3626430879586192),
#  ([(0.032565027, 'ev'),
#    (0.0210614, 'pneumoniae'),
#    (0.020241193, 'd68'),
#    (0.017919337, 'mp'),
#    (0.014319065, 'pv'),
#    (0.013142834, 'pneumococcal'),
#    (0.012789334, 'enterovirus'),
#    (0.012390812, 'mycoplasma'),
#    (0.009047396, 'pneumonia'),
#    (0.008678624, 'pleural'),
#    (0.007366439, 'children'),
#    (0.0070191757, 'fluid'),
#    (0.00696848, 'associated'),
#    (0.0069436817, 'pe'),
#    (0.006926536, 'virus'),
#    (0.0067506665, 'infection'),
#    (0.006726676, 'streptococcus'),
#    (0.0063928347, 'study'),
#    (0.006089753, 'effusion'),
#    (0.0060593975, 'vp2')],
#   0.3603427636786212),
#  ([(0.033952337, 'pilgrims'),
#    (0.023057, 'hajj'),
#    (0.02139862, 'suicide'),
#    (0.015581432, 'vaccination'),
#    (0.011573936, 'hhv'),
#    (0.009747351, 'cells'),
#    (0.009462576, 'saudi'),
#    (0.008591831, 'ire1'),
#    (0.007910579, 'gl'),
#    (0.0072994106, 'hk'),
#    (0.007110838, 'patch'),
#    (0.0070441924, 'mood'),
#    (0.005880383, 'mers'),
#    (0.0057804803, 'infection'),
#    (0.005744738, 'study'),
#    (0.0053756796, 'marginal'),
#    (0.0053330935, 'results'),
#    (0.0052359463, 'meningococcal'),
#    (0.0050294027, '6b'),
#    (0.0047427462, 'factors')],
#   0.3586746052453185),
#  ([(0.093815774, 'hrv'),
#    (0.0343029, 'wind'),
#    (0.018010171, 'building'),
#    (0.014731769, 'buildings'),
#    (0.013128171, 'clusters'),
#    (0.009296389, 'high'),
#    (0.008975593, 'caninum'),
#    (0.008659337, 'hrvs'),
#    (0.008499876, 'level'),
#    (0.008487463, 'study'),
#    (0.008171058, 'urban'),
#    (0.0071134656, 'cluster'),
#    (0.0069731004, 'boundary'),
#    (0.0066736443, 'pedestrian'),
#    (0.005919054, 'tunnel'),
#    (0.005782348, 'pups'),
#    (0.0057326346, 'density'),
#    (0.005633308, 'abstract'),
#    (0.0055558304, 'bear'),
#    (0.005461397, 'environment')],
#   0.35336389246473016),
#  ([(0.028397592, 'virus'),
#    (0.019372514, 'infection'),
#    (0.019173758, 'exon'),
#    (0.016059525, 'rna'),
#    (0.016003035, 'viral'),
#    (0.015237255, 'replication'),
#    (0.014950333, 'respiratory'),
#    (0.012088533, 'prcv'),
#    (0.010172936, 'infected'),
#    (0.008479354, 'positive'),
#    (0.0065586837, 'viruses'),
#    (0.0060500316, 'coronavirus'),
#    (0.0058421087, 'shedding'),
#    (0.0057975035, 'wu'),
#    (0.004734231, 'detected'),
#    (0.0046600006, 'study'),
#    (0.0046544806, 'disease'),
#    (0.0043886267, 'fidelity'),
#    (0.00432408, 'fitness'),
#    (0.004078287, 'polyomavirus')],
#   0.35124921372706397),
#  ([(0.015209936, 'respiratory'),
#    (0.012729965, 'ic'),
#    (0.0111531345, 'mediterranean'),
#    (0.010302134, 'infection'),
#    (0.010202426, 'region'),
#    (0.008729604, 'virus'),
#    (0.008232228, 'ethanol'),
#    (0.008097715, 'acute'),
#    (0.007932653, 'seizure'),
#    (0.0076114377, 'ips'),
#    (0.007218053, 'seizures'),
#    (0.0058168527, 'transmission'),
#    (0.0056026196, 'surfaces'),
#    (0.0053510894, 'jordan'),
#    (0.0052578924, 'eastern'),
#    (0.0050197416, 'infectious'),
#    (0.0049485313, 'polymer'),
#    (0.004886, 'abstract'),
#    (0.004745514, 'surface'),
#    (0.004527476, 'tract')],
#   0.34167985372803594),
#  ([(0.024701275, 'cells'),
#    (0.022062179, 'expression'),
#    (0.018637015, 'intestinal'),
#    (0.016966835, 'astrocytes'),
#    (0.009398198, 'gut'),
#    (0.009316863, 'lps'),
#    (0.008764653, 'cox'),
#    (0.008621259, 'epithelial'),
#    (0.0072686058, 'intestine'),
#    (0.0070834523, 'infection'),
#    (0.00684938, 'results'),
#    (0.0065585123, 'cordata'),
#    (0.006337972, 'cell'),
#    (0.00622265, 'study'),
#    (0.0057085445, 'epithelium'),
#    (0.0056543415, 'tlr4'),
#    (0.005355914, 'infected'),
#    (0.0052151917, 'increased'),
#    (0.005124081, 'immune'),
#    (0.004646567, 'ag')],
#   0.33005232294311815),
#  ([(0.04313408, 'data'),
#    (0.0140474895, 'mobile'),
#    (0.011658492, 'disease'),
#    (0.009684489, 'digital'),
#    (0.0071558347, 'sharing'),
#    (0.00659855, 'using'),
#    (0.006143453, 'surveillance'),
#    (0.006048586, 'signature'),
#    (0.0055157263, 'system'),
#    (0.0055019255, 'based'),
#    (0.005267717, 'network'),
#    (0.0051266905, 'development'),
#    (0.004727767, 'phone'),
#    (0.004601167, 'ppi'),
#    (0.0045902757, 'formaldehyde'),
#    (0.004536044, 'time'),
#    (0.0044416264, 'used'),
#    (0.004371128, 'collection'),
#    (0.0043709697, 'signatures'),
#    (0.0042545684, 'analysis')],
#   0.3270132368251521),
#  ([(0.012335734, 'model'),
#    (0.011257681, 'filter'),
#    (0.008027991, 'based'),
#    (0.00782766, 'time'),
#    (0.007345356, 'system'),
#    (0.006317243, 'abstract'),
#    (0.0058987443, 'microfluidic'),
#    (0.0056854445, 'new'),
#    (0.0055745705, 'using'),
#    (0.0052917777, 'used'),
#    (0.005220151, 'control'),
#    (0.0049407147, 'drop'),
#    (0.0049105203, 'also'),
#    (0.0048274617, 'two'),
#    (0.0047378517, 'method'),
#    (0.004537061, 'different'),
#    (0.0045005707, 'paper'),
#    (0.0042538913, 'layer'),
#    (0.0042275228, 'lab'),
#    (0.004216787, 'prices')],
#   0.32603632131615057),
#  ([(0.043010358, 'nk'),
#    (0.015459969, 'tick'),
#    (0.013163822, 'human'),
#    (0.0112109855, 'killer'),
#    (0.01089135, 'wound'),
#    (0.010072694, 'markets'),
#    (0.0080757765, 'h7n9'),
#    (0.007611, 'wet'),
#    (0.007582905, 'disease'),
#    (0.0075668776, 'cells'),
#    (0.006949084, 'ticks'),
#    (0.006716064, 'years'),
#    (0.0063127945, 'influenza'),
#    (0.006075112, 'alpacas'),
#    (0.005621769, 'paraffin'),
#    (0.0055988166, 'healing'),
#    (0.0055979067, 'embedded'),
#    (0.005088286, 'found'),
#    (0.005071568, 'plague'),
#    (0.004773244, 'formalin')],
#   0.32516366101938454),
#  ([(0.032968193, 'pregnancy'),
#    (0.023827465, 'pregnant'),
#    (0.021965256, 'women'),
#    (0.016844159, 'maternal'),
#    (0.013750571, 'van'),
#    (0.011042474, 'hand'),
#    (0.0098074665, 'hygiene'),
#    (0.008370884, 'asp'),
#    (0.008207632, 'fetal'),
#    (0.006575076, 'group'),
#    (0.0064397235, 'een'),
#    (0.006276512, 'birth'),
#    (0.0060891663, 'door'),
#    (0.0059356666, 'health'),
#    (0.0052769943, 'study'),
#    (0.005032326, 'facemasks'),
#    (0.004940617, 'gestation'),
#    (0.0049000764, 'infection'),
#    (0.0047892407, 'sars'),
#    (0.004756237, 'control')],
#   0.32284225951163825),
#  ([(0.026578989, 'kd'),
#    (0.02134533, 'vaccination'),
#    (0.013644751, 'kawasaki'),
#    (0.012259849, 'disease'),
#    (0.0121669555, 'bcg'),
#    (0.009629172, 'vasculitis'),
#    (0.008694281, 'coronary'),
#    (0.008458416, 'clinical'),
#    (0.008313392, 'allograft'),
#    (0.0075649857, 'infectious'),
#    (0.0067792675, 'strategies'),
#    (0.006727789, 'ivig'),
#    (0.006588268, 'risk'),
#    (0.006552033, 'childhood'),
#    (0.006340161, 'mucus'),
#    (0.006018043, 'children'),
#    (0.0058689914, 'rejection'),
#    (0.00526328, 'anemia'),
#    (0.0052250684, 'artery'),
#    (0.004750811, 'factors')],
#   0.31567815101715574),
#  ([(0.052459836, 'hbov'),
#    (0.032415554, 'ferret'),
#    (0.028733468, 'ferrets'),
#    (0.022057489, 'bocavirus'),
#    (0.015687315, 'hbov1'),
#    (0.013773976, 'human'),
#    (0.010777306, 'hp'),
#    (0.008322029, 'study'),
#    (0.0075900764, 'app'),
#    (0.007489011, 'infection'),
#    (0.007141765, 'respiratory'),
#    (0.0061442913, 'using'),
#    (0.0059772707, 'children'),
#    (0.0058203074, 'results'),
#    (0.005279658, 'scfv'),
#    (0.005111807, 'infections'),
#    (0.0050865854, 'detected'),
#    (0.0047952295, 'two'),
#    (0.0045230477, 'mmp'),
#    (0.0044688154, 'dna')],
#   0.3099979166019545),
#  ([(0.058550626, 'cancer'),
#    (0.013074571, 'tumor'),
#    (0.011214445, 'treatment'),
#    (0.011102652, 'hbv'),
#    (0.00968798, 'clinical'),
#    (0.008897159, 'hpv'),
#    (0.008380124, 'igy'),
#    (0.008293747, 'cat'),
#    (0.0077633196, 'muscle'),
#    (0.007295964, 'disease'),
#    (0.0053617363, 'therapy'),
#    (0.005123668, 'cell'),
#    (0.0050781383, 'cancers'),
#    (0.004993241, 'associated'),
#    (0.004958516, 'rabbits'),
#    (0.0049300343, 'diseases'),
#    (0.0047691436, 'effects'),
#    (0.0043276185, 'prostate'),
#    (0.004281104, 'also'),
#    (0.0041645356, 'disorders')],
#   0.29559083657623636),
#  ([(0.012548676, 'ad'),
#    (0.010346009, 'nasal'),
#    (0.008660136, 'chapter'),
#    (0.0080814995, 'disorder'),
#    (0.0066305385, 'diagnostic'),
#    (0.0059717763, 'pharyngitis'),
#    (0.0055238726, 'clinical'),
#    (0.0047894823, 'postmortem'),
#    (0.004416723, 'may'),
#    (0.004281277, 'measures'),
#    (0.0042632353, 'specific'),
#    (0.004137638, 'cases'),
#    (0.0041030706, 'amyloid'),
#    (0.003928468, 'history'),
#    (0.0038826098, 'laboratory'),
#    (0.003869404, 'results'),
#    (0.0037879641, 'chapters'),
#    (0.003654358, 'two'),
#    (0.0036206779, 'diagnosis'),
#    (0.0035693038, 'disease')],
#   0.2933549065049853),
#  ([(0.032330345, 'ev71'),
#    (0.0251698, 'ebv'),
#    (0.016720029, 'infection'),
#    (0.014154795, 'replication'),
#    (0.01355164, 'virus'),
#    (0.011861214, 'cyclophilin'),
#    (0.011748148, 'reovirus'),
#    (0.011277464, 'ns1'),
#    (0.011020772, 'cypa'),
#    (0.01097007, 'mouth'),
#    (0.010731151, 'foot'),
#    (0.010333648, 'akt'),
#    (0.009756803, 'enterovirus'),
#    (0.009698246, 'barr'),
#    (0.009563114, 'epstein'),
#    (0.009239906, 'pi3k'),
#    (0.009194037, 'csa'),
#    (0.00765983, 'fmdv'),
#    (0.0071209627, 'host'),
#    (0.0062398505, 'kinase')],
#   0.2884468554554491),
#  ([(0.02286158, 'tourism'),
#    (0.017767463, 'bone'),
#    (0.015308566, 'vaccine'),
#    (0.011332133, 'marrow'),
#    (0.009670502, 'injection'),
#    (0.0093514295, 'vaccines'),
#    (0.009310365, 'study'),
#    (0.0081853485, 'mva'),
#    (0.008006411, 'dna'),
#    (0.007458593, 'prime'),
#    (0.0070579755, 'cd13'),
#    (0.00702431, 'vaccination'),
#    (0.006829354, 'dose'),
#    (0.0062820204, 'boost'),
#    (0.00567653, 'ia'),
#    (0.005563337, 'abstract'),
#    (0.0050176783, 'cell'),
#    (0.0049880007, 'results'),
#    (0.0049374285, 'demand'),
#    (0.0047977255, 'travel')],
#   0.2826667813611077),
#  ([(0.036522165, 'h5n1'),
#    (0.01686754, 'influenza'),
#    (0.015317039, 'avian'),
#    (0.014066241, 'allergic'),
#    (0.011279597, 'young'),
#    (0.010465009, 'hong'),
#    (0.009601658, 'human'),
#    (0.009570833, 'rhinitis'),
#    (0.009373269, 'park'),
#    (0.008049074, 'pandemic'),
#    (0.008025495, 'ige'),
#    (0.007834616, 'india'),
#    (0.007459086, 'poultry'),
#    (0.007370045, 'kong'),
#    (0.0064167334, 'disease'),
#    (0.006398716, 'vietnam'),
#    (0.006132284, 'hpai'),
#    (0.005818756, 'atopic'),
#    (0.0057552033, 'study'),
#    (0.0053738193, 'allergy')],
#   0.2669752624699942),
#  ([(0.01886187, 'de'),
#    (0.012222215, 'et'),
#    (0.010919642, 'health'),
#    (0.00934122, 'la'),
#    (0.00842581, 'des'),
#    (0.006150488, 'research'),
#    (0.006131153, 'en'),
#    (0.006006609, 'new'),
#    (0.005967104, 'les'),
#    (0.0056694294, 'global'),
#    (0.005595122, 'diseases'),
#    (0.0054818783, 'development'),
#    (0.0050187656, 'infectious'),
#    (0.0048364247, 'disease'),
#    (0.0041414667, 'international'),
#    (0.0035261142, 'clinical'),
#    (0.0033556775, 'le'),
#    (0.0032654866, 'surveillance'),
#    (0.0031909554, 'world'),
#    (0.0029555508, 'meeting')],
#   0.2634386640815808)]
